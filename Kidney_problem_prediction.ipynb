# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/deshm/Desktop/dataml/kidney_disease.csv')
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df['classification'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(df['classification'])
# Out:
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='classification', ylabel='count'>
# C:\Users\deshm\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\deshm\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
df.head(2)
# Out:
#    id   age    bp    sg   al   su  rbc      pc         pcc          ba    bgr  \
# 0   0  48.0  80.0  1.02  1.0  0.0  NaN  normal  notpresent  notpresent  121.0
# 1   1   7.0  50.0  1.02  4.0  0.0  NaN  normal  notpresent  notpresent    NaN
#
#      bu   sc  sod  pot  hemo pcv    wc   rc  htn   dm cad appet  pe ane  \
# 0  36.0  1.2  NaN  NaN  15.4  44  7800  5.2  yes  yes  no  good  no  no
# 1  18.0  0.8  NaN  NaN  11.3  38  6000  NaN   no   no  no  good  no  no
#
#   classification
# 0            ckd
# 1            ckd

# %%
df.shape
# Out:
# (400, 26)

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
null_col=df.isnull().sum()/df.shape[0]*100
null_col
# Out:
# id                 0.00
# age                2.25
# bp                 3.00
# sg                11.75
# al                11.50
# su                12.25
# rbc               38.00
# pc                16.25
# pcc                1.00
# ba                 1.00
# bgr               11.00
# bu                 4.75
# sc                 4.25
# sod               21.75
# pot               22.00
# hemo              13.00
# pcv               17.50
# wc                26.25
# rc                32.50
# htn                0.50
# dm                 0.50
# cad                0.50
# appet              0.25
# pe                 0.25
# ane                0.25
# classification     0.00
# dtype: float64

# %%
null_col2=null_col[null_col>18].keys()
null_col2
# Out:
# Index(['rbc', 'sod', 'pot', 'wc', 'rc'], dtype='object')

# %%
df2=df.drop(columns=null_col2)
df2.head()
# Out:
#    id   age    bp     sg   al   su        pc         pcc          ba    bgr  \
# 0   0  48.0  80.0  1.020  1.0  0.0    normal  notpresent  notpresent  121.0
# 1   1   7.0  50.0  1.020  4.0  0.0    normal  notpresent  notpresent    NaN
# 2   2  62.0  80.0  1.010  2.0  3.0    normal  notpresent  notpresent  423.0
# 3   3  48.0  70.0  1.005  4.0  0.0  abnormal     present  notpresent  117.0
# 4   4  51.0  80.0  1.010  2.0  0.0    normal  notpresent  notpresent  106.0
#
#      bu   sc  hemo pcv  htn   dm cad appet   pe  ane classification
# 0  36.0  1.2  15.4  44  yes  yes  no  good   no   no            ckd
# 1  18.0  0.8  11.3  38   no   no  no  good   no   no            ckd
# 2  53.0  1.8   9.6  31   no  yes  no  poor   no  yes            ckd
# 3  56.0  3.8  11.2  32  yes   no  no  poor  yes  yes            ckd
# 4  26.0  1.4  11.6  35   no   no  no  good   no   no            ckd

# %%
df2.shape
# Out:
# (400, 21)

# %%
sns.heatmap(df2.isnull())
# Out:
# <AxesSubplot:>

# %%
df2.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# hemo              float64
# pcv                object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %% [markdown]
# # Numerical val

# %%
num_val_df3 =df2.select_dtypes(include=['int64','float64'])
num_val_df3.head(2)
# Out:
#    id   age    bp    sg   al   su    bgr    bu   sc  hemo
# 0   0  48.0  80.0  1.02  1.0  0.0  121.0  36.0  1.2  15.4
# 1   1   7.0  50.0  1.02  4.0  0.0    NaN  18.0  0.8  11.3

# %%
sns.heatmap(num_val_df3.isnull())
# Out:
# <AxesSubplot:>

# %%
num_val_df3.isnull().sum()
# Out:
# id       0
# age      9
# bp      12
# sg      47
# al      46
# su      49
# bgr     44
# bu      19
# sc      17
# hemo    52
# dtype: int64

# %%
miss_val_col=[var for var in num_val_df3.columns if num_val_df3[var].isnull().sum()>0]
miss_val_col
# Out:
# ['age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'hemo']

# %%
for i ,val in enumerate(miss_val_col):
    plt.figure(figsize=(19,6))
    
    sns.distplot(num_val_df3[val],bins=20)
# Out:
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df4_mean=num_val_df3.fillna(num_val_df3.mean())
df4_mean.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(df4_mean.isnull())
# Out:
# <AxesSubplot:>

# %%
for i ,val in enumerate(miss_val_col):
    plt.figure(figsize=(6,6))
    
    sns.distplot(num_val_df3[val],bins=20,label="orignal")
    sns.distplot(df4_mean[val],bins=20,label="mean")
    plt.legend()
# Out:
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df2.update(df4_mean)
df2.isnull().sum()
# Out:
# id                 0
# age                0
# bp                 0
# sg                 0
# al                 0
# su                 0
# pc                65
# pcc                4
# ba                 4
# bgr                0
# bu                 0
# sc                 0
# hemo               0
# pcv               70
# htn                2
# dm                 2
# cad                2
# appet              1
# pe                 1
# ane                1
# classification     0
# dtype: int64

# %%
sns.heatmap(df2.isnull())
# Out:
# <AxesSubplot:>

# %%
original_cat=df2.select_dtypes(include=['object'])
original_cat.isnull().sum()
# Out:
# pc                65
# pcc                4
# ba                 4
# pcv               70
# htn                2
# dm                 2
# cad                2
# appet              1
# pe                 1
# ane                1
# classification     0
# dtype: int64

# %% [markdown]
# # categorical val

# %%
cat_val_df3 =df2.select_dtypes(include=['object'])
cat_val_df3.head(2)
# Out:
#        pc         pcc          ba pcv  htn   dm cad appet  pe ane  \
# 0  normal  notpresent  notpresent  44  yes  yes  no  good  no  no
# 1  normal  notpresent  notpresent  38   no   no  no  good  no  no
#
#   classification
# 0            ckd
# 1            ckd

# %%
sns.heatmap(cat_val_df3.isnull())
# Out:
# <AxesSubplot:>

# %%
miss_cat_val=cat_val_df3.isnull().mean()*100
miss_cat_val
# Out:
# pc                16.25
# pcc                1.00
# ba                 1.00
# pcv               17.50
# htn                0.50
# dm                 0.50
# cad                0.50
# appet              0.25
# pe                 0.25
# ane                0.25
# classification     0.00
# dtype: float64

# %%
miss_val=miss_cat_val[miss_cat_val>0].keys()
miss_val
# Out:
# Index(['pc', 'pcc', 'ba', 'pcv', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane'], dtype='object')

# %%
for i in miss_val:
   cat_val_df3[i].fillna(cat_val_df3[i].mode()[0] ,inplace=True)
   print(i+" =",cat_val_df3[i].mode()[0])
# Out:
# pc = normal
# pcc = notpresent
# ba = notpresent
# pcv = 41
# htn = no
# dm = no
# cad = no
# appet = good
# pe = no
# ane = no
# C:\Users\deshm\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
cat_val_df3.isnull().sum()
# Out:
# pc                0
# pcc               0
# ba                0
# pcv               0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
plt.figure(figsize=(16,9))
for i ,val in enumerate(miss_val):
    
    plt.subplot(4,3,i+1)
    plt.hist(df[val].dropna(),label='original')
    plt.hist(cat_val_df3[val],label='updated')
    plt.legend()
# Out:
# C:\Users\deshm\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\deshm\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df2.update(cat_val_df3)
df2.isnull().sum()
# Out:
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# hemo              0
# pcv               0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
sns.heatmap(df2.isnull())
# Out:
# <AxesSubplot:>

# %%
df2.head()
# Out:
#    id   age    bp     sg   al   su        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0    normal  notpresent  notpresent
#
#           bgr    bu   sc  hemo pcv  htn   dm cad appet   pe  ane  \
# 0  121.000000  36.0  1.2  15.4  44  yes  yes  no  good   no   no
# 1  148.036517  18.0  0.8  11.3  38   no   no  no  good   no   no
# 2  423.000000  53.0  1.8   9.6  31   no  yes  no  poor   no  yes
# 3  117.000000  56.0  3.8  11.2  32  yes   no  no  poor  yes  yes
# 4  106.000000  26.0  1.4  11.6  35   no   no  no  good   no   no
#
#   classification
# 0            ckd
# 1            ckd
# 2            ckd
# 3            ckd
# 4            ckd

# %% [markdown]
# # LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder_Y=LabelEncoder()
for i in  cat_val_df3:
  
   df2[i]=labelEncoder_Y.fit_transform(df2[i])

# %%
df2.shape
# Out:
# (400, 21)

# %%
df2.head()
# Out:
#    id   age    bp     sg   al   su  pc  pcc  ba         bgr    bu   sc  hemo  \
# 0   0  48.0  80.0  1.020  1.0  0.0   1    0   0  121.000000  36.0  1.2  15.4
# 1   1   7.0  50.0  1.020  4.0  0.0   1    0   0  148.036517  18.0  0.8  11.3
# 2   2  62.0  80.0  1.010  2.0  3.0   1    0   0  423.000000  53.0  1.8   9.6
# 3   3  48.0  70.0  1.005  4.0  0.0   0    1   0  117.000000  56.0  3.8  11.2
# 4   4  51.0  80.0  1.010  2.0  0.0   1    0   0  106.000000  26.0  1.4  11.6
#
#    pcv  htn  dm  cad  appet  pe  ane  classification
# 0   32    1   4    1      0   0    0               0
# 1   26    0   3    1      0   0    0               0
# 2   19    0   4    1      1   0    1               0
# 3   20    1   3    1      1   1    1               0
# 4   23    0   3    1      0   0    0               0

# %% [markdown]
# # visualisations

# %%
sns.pairplot(df , hue="classification", height=3, aspect=1);
# Out:
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df2.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   16.974966   13.476298    0.005369    1.272318    1.029487
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.015000    0.000000    0.000000
# 50%    199.500000   54.000000   78.234536    1.017408    1.000000    0.000000
# 75%    299.250000   64.000000   80.000000    1.020000    2.000000    0.450142
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#                pc         pcc          ba         bgr          bu          sc  \
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.000000
# mean     0.810000    0.105000    0.055000  148.036517   57.425722    3.072454
# ...

# %%
df2.corr()
# Out:
#                       id       age        bp        sg        al        su  \
# id              1.000000 -0.184043 -0.243732  0.613623 -0.520040 -0.271330
# age            -0.184043  1.000000  0.148004 -0.180570  0.114764  0.207857
# bp             -0.243732  0.148004  1.000000 -0.182463  0.146593  0.200784
# sg              0.613623 -0.180570 -0.182463  1.000000 -0.466698 -0.287993
# al             -0.520040  0.114764  0.146593 -0.466698  1.000000  0.268070
# su             -0.271330  0.207857  0.200784 -0.287993  0.268070  1.000000
# pc              0.335825 -0.101951 -0.156856  0.345325 -0.535157 -0.168826
# pcc            -0.264142  0.159074  0.059560 -0.290663  0.399749  0.151445
# ba             -0.115955  0.043573  0.112173 -0.220792  0.367855  0.107684
# bgr            -0.319937  0.214410  0.149100 -0.326339  0.326400  0.639186
# bu             -0.300943  0.187544  0.183970 -0.278568  0.405778  0.152186
# ...

# %% [markdown]
# # feature  selection

# %%
plt.figure(figsize=(19,9))
sns.heatmap(df2.corr(), annot=True, linewidths=0.3,
    linecolor='white',)
# Out:
# <AxesSubplot:>

# %%
df2.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'hemo', 'pcv', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane',
#        'classification'],
#       dtype='object')

# %%
X=df2.drop(['classification','id'],axis=1)
#print(X.shape)
#pd.set_option('display.max_columns',None)
#pd.set_option('display.max_row',None)
#print(X.columns)
#print(X)

Y=df2['classification']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25)

# %% [markdown]
# # feature scalling

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test  = sc.fit_transform(X_test)
X_train
# Out:
# array([[ 0.61990488,  0.23929704, -1.41167523, ..., -0.48956044,
#         -0.4632223 , -0.38655567],
#        [ 0.50117252,  0.95089745,  0.0118308 , ..., -0.48956044,
#          2.15879072, -0.38655567],
#        [-0.00442691, -0.47230338,  0.50992181, ..., -0.48956044,
#         -0.4632223 , -0.38655567],
#        ...,
#        [ 0.20434163, -0.47230338, -1.41167523, ...,  2.04264872,
#          2.15879072, -0.38655567],
#        [-0.32995398, -1.18390379,  1.47072033, ..., -0.48956044,
#         -0.4632223 , -0.38655567],
#        [ 0.73863723, -0.47230338,  0.0118308 , ..., -0.48956044,
#          2.15879072,  2.5869495 ]])

# %% [markdown]
# # model selection

# %%
def models(X_train,Y_train):

 
 from sklearn.linear_model import LogisticRegression
 log = LogisticRegression(random_state=0)
 log.fit(X_train,Y_train)

 from sklearn.tree import DecisionTreeClassifier
 tree=DecisionTreeClassifier( criterion= 'entropy',random_state=0 )
 tree.fit(X_train,Y_train)

 from sklearn.ensemble import RandomForestClassifier
 forest=RandomForestClassifier(n_estimators=10,criterion= 'entropy' ,random_state=0)
 forest.fit(X_train,Y_train)


 print('[0] LinearRegressionear_model',log.score(X_train,Y_train))
 print('[1]  DecisionTreeClassifier_model',tree.score(X_train,Y_train))
 print('[2] RandomForestRegressor_model',forest.score(X_train,Y_train))
    
 return log, tree, forest 

model=models(X_train, Y_train)
# Out:
# [0] LinearRegressionear_model 1.0
# [1]  DecisionTreeClassifier_model 1.0
# [2] RandomForestRegressor_model 1.0

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
for i in range(len(model)):
 print(classification_report(Y_test , model[0].predict(X_test)))
 print(accuracy_score(Y_test , model[0].predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        57
#            1       0.00      0.00      0.00         2
#            2       0.98      1.00      0.99        41
#
#     accuracy                           0.97       100
#    macro avg       0.65      0.66      0.65       100
# weighted avg       0.95      0.97      0.96       100
#
# 0.97
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        57
#            1       0.00      0.00      0.00         2
#            2       0.98      1.00      0.99        41
#
#     accuracy                           0.97       100
#    macro avg       0.65      0.66      0.65       100
# weighted avg       0.95      0.97      0.96       100
#
# 0.97
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        57
#            1       0.00      0.00      0.00         2
# ...

# %%
pred=model[2].predict(X_test)
print (pred)
print()
# Out:
# [0 2 2 0 0 2 0 0 0 0 2 0 0 2 0 2 0 0 0 2 2 0 2 0 0 2 0 0 0 0 2 0 2 2 0 0 2
#  0 2 2 2 0 2 0 0 0 2 2 0 2 2 2 2 0 0 0 2 2 0 0 0 2 0 0 2 2 2 2 2 0 0 0 2 0
#  2 0 2 2 0 0 0 0 0 2 2 2 2 0 0 0 0 0 2 2 0 0 0 0 0 0]

# %%
pred=model[0].predict(X_test)
df4=pd.DataFrame(pred)

df5=pd.DataFrame(Y_test)


print (df4.value_counts())
print(df5.value_counts())

sns.distplot(df4,color='black',label='predict-x_test')
sns.distplot(df5,color='green',label='y_test')
plt.legend()
# Out:
# 0    58
# 2    42
# dtype: int64
# classification
# 0                 57
# 2                 41
# 1                  2
# dtype: int64
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
  #v=[  48.000000 ,  80.000000 , 1.020000 , 1.000000 , 0.000000,   1  ,  0   ,0 , 1.000000 , 0.000000,   1  ,  0   ,0, 1.000000 , 0.000000,  1, 1  ,  0   ,0]
  v=df2.iloc[1,1:20]
  print(v)
  na=np.asarray(v)

  input_rsd=na.reshape(1,-1)

  pred=model[1].predict(input_rsd)
  print(pred)
# Out:
# age        7.000000
# bp        50.000000
# sg         1.020000
# al         4.000000
# su         0.000000
# pc         1.000000
# pcc        0.000000
# ba         0.000000
# bgr      148.036517
# bu        18.000000
# sc         0.800000
# hemo      11.300000
# pcv       26.000000
# htn        0.000000
# dm         3.000000
# cad        1.000000
# appet      0.000000
# pe         0.000000
# ane        0.000000
# Name: 1, dtype: float64
# [2]
